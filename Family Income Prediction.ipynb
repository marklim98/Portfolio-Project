# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression, Ridge, Lasso, HuberRegressor
from sklearn.svm import LinearSVR
from sklearn.tree import DecisionTreeRegressor

# %%
#Data from Kaggle.com
df = pd.read_csv("Family Income and Expenditure.csv")
df.head()
# Out:
#    Total Household Income Region  Total Food Expenditure  \
# 0                  480332    CAR                  117848
# 1                  198235    CAR                   67766
# 2                   82785    CAR                   61609
# 3                  107589    CAR                   78189
# 4                  189322    CAR                   94625
#
#   Main Source of Income  Agricultural Household indicator  \
# 0         Wage/Salaries                                 0
# 1         Wage/Salaries                                 0
# 2         Wage/Salaries                                 1
# 3         Wage/Salaries                                 0
# 4         Wage/Salaries                                 0
#
#    Bread and Cereals Expenditure  Total Rice Expenditure  Meat Expenditure  \
# 0                          42140                   38300             24676
# 1                          17329                   13008             17434
# ...

# %%
df.groupby("Region")["Region"].agg("count")
# Out:
# Region
#  ARMM                        2248
# CAR                          1725
# Caraga                       1782
# I - Ilocos Region            2348
# II - Cagayan Valley          2219
# III - Central Luzon          3237
# IVA - CALABARZON             4162
# IVB - MIMAROPA               1249
# IX - Zasmboanga Peninsula    1788
# NCR                          4130
# V - Bicol Region             2472
# VI - Western Visayas         2851
# VII - Central Visayas        2541
# VIII - Eastern Visayas       2337
# X - Northern Mindanao        1887
# XI - Davao Region            2446
# XII - SOCCSKSARGEN           2122
# Name: Region, dtype: int64

# %%
df.groupby("Main Source of Income")["Main Source of Income"].agg("count")
# Out:
# Main Source of Income
# Enterpreneurial Activities    10320
# Other sources of Income       10836
# Wage/Salaries                 20388
# Name: Main Source of Income, dtype: int64

# %%
df.groupby("Household Head Sex")["Household Head Sex"].agg("count")
# Out:
# Household Head Sex
# Female     9061
# Male      32483
# Name: Household Head Sex, dtype: int64

# %%
df.groupby("Household Head Marital Status")["Household Head Marital Status"].agg("count")
# Out:
# Household Head Marital Status
# Annulled                 11
# Divorced/Separated     1425
# Married               31347
# Single                 1942
# Unknown                   1
# Widowed                6818
# Name: Household Head Marital Status, dtype: int64

# %%
df.groupby("Household Head Highest Grade Completed")["Household Head Highest Grade Completed"].agg("count")
# Out:
# Household Head Highest Grade Completed
# Agriculture, Forestry, and Fishery Programs                                                                                                                                                                             230
# Architecture and Building Programs                                                                                                                                                                                       33
# Arts Programs                                                                                                                                                                                                            23
# Basic Programs                                                                                                                                                                                                           33
# ...

# %%
df.groupby("Household Head Job or Business Indicator")["Household Head Job or Business Indicator"].agg("count")
# Out:
# Household Head Job or Business Indicator
# No Job/Business       7536
# With Job/Business    34008
# Name: Household Head Job or Business Indicator, dtype: int64

# %%
df.groupby("Household Head Class of Worker")["Household Head Class of Worker"].agg("count")
# Out:
# Household Head Class of Worker
# Employer in own family-operated farm or business               2581
# Self-employed wihout any employee                             13766
# Worked for government/government corporation                   2820
# Worked for private establishment                              13731
# Worked for private household                                    811
# Worked with pay in own family-operated farm or business          14
# Worked without pay in own family-operated farm or business      285
# Name: Household Head Class of Worker, dtype: int64

# %%
df.groupby("Type of Household")["Type of Household"].agg("count")
# Out:
# Type of Household
# Extended Family                           12932
# Single Family                             28445
# Two or More Nonrelated Persons/Members      167
# Name: Type of Household, dtype: int64

# %%
df.groupby("Type of Building/House")["Type of Building/House"].agg("count")
# Out:
# Type of Building/House
# Commercial/industrial/agricultural building       51
# Duplex                                          1084
# Institutional living quarter                       9
# Multi-unit residential                          1329
# Other building unit (e.g. cave, boat)              2
# Single house                                   39069
# Name: Type of Building/House, dtype: int64

# %%
df.groupby("Type of Roof")["Type of Roof"].agg("count")
# Out:
# Type of Roof
# Light material (cogon,nipa,anahaw)                                         5074
# Mixed but predominantly light materials                                     846
# Mixed but predominantly salvaged materials                                   56
# Mixed but predominantly strong materials                                   2002
# Not Applicable                                                               12
# Salvaged/makeshift materials                                                212
# Strong material(galvanized,iron,al,tile,concrete,brick,stone,asbestos)    33342
# Name: Type of Roof, dtype: int64

# %%
df.groupby("Type of Walls")["Type of Walls"].agg("count")
# Out:
# Type of Walls
# Light              8267
# NOt applicable       12
# Quite Strong       3487
# Salvaged            456
# Strong            27739
# Very Light         1583
# Name: Type of Walls, dtype: int64

# %%
df.groupby("Tenure Status")["Tenure Status"].agg("count")
# Out:
# Tenure Status
# Not Applicable                                          73
# Own house, rent lot                                    425
# Own house, rent-free lot with consent of owner        6165
# Own house, rent-free lot without consent of owner      995
# Own or owner-like possession of house and lot        29541
# Rent house/room including lot                         2203
# Rent-free house and lot with consent of owner         2014
# Rent-free house and lot without consent of owner       128
# Name: Tenure Status, dtype: int64

# %%
df.groupby("Main Source of Water Supply")["Main Source of Water Supply"].agg("count")
# Out:
# Main Source of Water Supply
# Dug well                                    3876
# Lake, river, rain and others                 496
# Others                                       127
# Own use, faucet, community water system    16093
# Own use, tubed/piped deep well              4587
# Peddler                                      851
# Protected spring, river, stream, etc        2657
# Shared, faucet, community water system      4614
# Shared, tubed/piped deep well               6242
# Tubed/piped shallow well                    1394
# Unprotected spring, river, stream, etc       607
# Name: Main Source of Water Supply, dtype: int64

# %%
df1 = df.dropna()
df1.isnull().sum()
# Out:
# Total Household Income                           0
# Region                                           0
# Total Food Expenditure                           0
# Main Source of Income                            0
# Agricultural Household indicator                 0
# Bread and Cereals Expenditure                    0
# Total Rice Expenditure                           0
# Meat Expenditure                                 0
# Total Fish and  marine products Expenditure      0
# Fruit Expenditure                                0
# Vegetables Expenditure                           0
# Restaurant and hotels Expenditure                0
# Alcoholic Beverages Expenditure                  0
# Tobacco Expenditure                              0
# Clothing, Footwear and Other Wear Expenditure    0
# Housing and water Expenditure                    0
# Imputed House Rental Value                       0
# Medical Care Expenditure                         0
# ...

# %%
df1 = df1.drop(["Household Head Occupation", "Toilet Facilities", "Main Source of Water Supply", "Number of CD/VCD/DVD", "Number of Component/Stereo set", "Number of Motorized Banca"], axis="columns")

# %%
df1.isnull().sum()
# Out:
# Total Household Income                           0
# Region                                           0
# Total Food Expenditure                           0
# Main Source of Income                            0
# Agricultural Household indicator                 0
# Bread and Cereals Expenditure                    0
# Total Rice Expenditure                           0
# Meat Expenditure                                 0
# Total Fish and  marine products Expenditure      0
# Fruit Expenditure                                0
# Vegetables Expenditure                           0
# Restaurant and hotels Expenditure                0
# Alcoholic Beverages Expenditure                  0
# Tobacco Expenditure                              0
# Clothing, Footwear and Other Wear Expenditure    0
# Housing and water Expenditure                    0
# Imputed House Rental Value                       0
# Medical Care Expenditure                         0
# ...

# %%
df1 = df1.replace({"Region" : {
    " ARMM" : 1,
    "ARMM" : 1,
    "CAR" : 2,
    "Caraga" : 3,
    "I - Ilocos Region" : 4,
    "II - Cagayan Valley" : 5,
    "III - Central Luzon" : 6,
    "IVA - CALABARZON" : 7,
    "IVB - MIMAROPA" : 8,
    "IX - Zasmboanga Peninsula" : 9,
    "NCR" : 10,
    "V - Bicol Region" : 11,
    "VI - Western Visayas" : 12,
    "VII - Central Visayas" : 13,
    "VIII - Eastern Visayas" : 14,
    "X - Northern Mindanao" : 15,
    "XI - Davao Region" : 16,
    "XII - SOCCSKSARGEN" : 17
}})

# %%
df1 = df1.replace({"Main Source of Income" : {
    "Enterpreneurial Activities" : 1,
    "Other sources of Income" : 2,
    "Wage/Salaries" : 3
}})

# %%
df1 = df1.replace({"Household Head Sex" : {
    "Female" : 1,
    "Male" : 2
}})

# %%
df1 = df1.replace({"Household Head Marital Status" : {
    "Annulled" : 1,
    "Divorced/Separated" : 2,
    "Married" : 3,
    "Single" : 4,
    "Unknown" : 5,
    "Widowed" : 6
}})

# %%
df1 = df1.replace({"Household Head Highest Grade Completed" : {
    "Agriculture, Forestry, and Fishery Programs" : 1,
    "Architecture and Building Programs" : 2,
    "Arts Programs" : 3,
    "Basic Programs" : 4,
    "Business and Administration Programs" : 5,
    "Computing/Information Technology Programs" : 6,
    "Elementary Graduate" : 7,
    "Engineering and Engineering Trades Programs" : 8,
    "Engineering and Engineering trades Programs" : 8,
    "Environmental Protection Programs" : 10,
    "First Year College" : 11,
    "First Year High School" : 12,
    "First Year Post Secondary" : 13,
    "Fourth Year College" : 14,
    "Grade 1" : 15,
    "Grade 2" : 16,
    "Grade 3" : 17,
    "Grade 4" : 18,
    "Grade 5" : 19,
    "Grade 6" : 20,
    "Health Programs" : 21,
    "High School Graduate" : 22,
    "Humanities Programs" : 23,
    "Journalism and Information Programs" : 24,
    "Law Programs" : 25,
    "Life Sciences Programs" : 26,
    "Manufacturing and Processing Programs" : 27,
    "Mathematics and Statistics Programs" : 28,
    "No Grade Completed" : 29,
    "Other Programs in Education at the Third Level, First Stage, of the Type that Leads to an Award not Equivalent to a First University or Baccalaureate Degree" : 30,
    "Other Programs of Education at the Third Level, First Stage, of the Type that Leads to a Baccalaureate or First University/Professional Degree (HIgher Education Level, First Stage, or Collegiate Education Level)" : 31,
    "Personal Services Programs" : 32,
    "Physical Sciences Programs" : 33,
    "Post Baccalaureate" : 34,
    "Preschool" : 19,
    "Second Year College" : 20,
    "Second Year High School" : 21,
    "Second Year Post Secondary" : 22,
    "Security Services Programs" : 23,
    "Social Services Programs" : 24,
    "Social and Behavioral Science Programs" : 25,
    "Teacher Training and Education Sciences Programs" : 26,
    "Third Year College" : 27,
    "Third Year High School" : 28,
    "Transport Services Programs" : 29,
    "Veterinary Programs" : 30
}})

# %%
df1 = df1.replace({"Household Head Job or Business Indicator" : {
    "No Job/Business" : 1,
    "With Job/Business" : 2
}})

# %%
df1 = df1.replace({"Household Head Class of Worker" : {
    "Employer in own family-operated farm or business" : 1,
    "Self-employed wihout any employee" : 2,
    "Worked for government/government corporation" : 3,
    "Worked for private establishment" : 4,
    "Worked for private household" : 5,
    "Worked with pay in own family-operated farm or business" : 6,
    "Worked without pay in own family-operated farm or business" : 7
}})

# %%
df1 = df1.replace({"Type of Household" : {
    "Extended Family" : 1,
    "Single Family" : 2,
    "Two or More Nonrelated Persons/Members" : 3
}})

# %%
df1 = df1.replace({"Type of Building/House" : {
    "Commercial/industrial/agricultural building" : 1,
    "Duplex" : 2,
    "Institutional living quarter" : 3,
    "Multi-unit residential" : 4,
    "Other building unit (e.g. cave, boat)" : 5,
    "Single house" : 6
}})

# %%
df1 = df1.replace({"Type of Roof" : {
    "Light material (cogon,nipa,anahaw)" : 1,
    "Mixed but predominantly light materials" : 2,
    "Mixed but predominantly salvaged materials" : 3,
    "Mixed but predominantly strong materials" : 4,
    "Not Applicable" : 5,
    "Salvaged/makeshift materials" : 6,
    "Strong material(galvanized,iron,al,tile,concrete,brick,stone,asbestos)" : 7
}})

# %%
df1 = df1.replace({"Type of Walls" : {
    "Light" : 1,
    "NOt applicable" : 2,
    "Quite Strong" : 3,
    "Salvaged" : 4,
    "Strong" : 5,
    "Very Light" : 6
}})

# %%
df1 = df1.replace({"Tenure Status" : {
    "Not Applicable" : 1,
    "Own house, rent lot" : 2,
    "Own house, rent-free lot with consent of owner" : 3,
    "Own house, rent-free lot without consent of owner" : 4,
    "Own or owner-like possession of house and lot" : 5,
    "Rent house/room including lot" : 6,
    "Rent-free house and lot with consent of owner" : 7,
    "Rent-free house and lot without consent of owner" : 8
}})

# %%
'''
df1 = df1.replace({"Main Source of Water Supply" : {
    "Dug well" : 1,
    "Lake, river, rain and others" : 2,
    "Others" : 3,
    "Own use, faucet, community water system" : 4,
    "Own use, tubed/piped deep well" : 5,
    "Peddler" : 6,
    "Protected spring, river, stream, etc" : 7,
    "Shared, faucet, community water system" : 8,
    "Shared, tubed/piped deep well" : 9,
    "Tubed/piped shallow well" : 10,
    "Unprotected spring, river, stream, etc" : 11
}})
'''

# %%
#df1 = df1.dropna()
df1.isnull().sum()
# Out:
# Total Household Income                           0
# Region                                           0
# Total Food Expenditure                           0
# Main Source of Income                            0
# Agricultural Household indicator                 0
# Bread and Cereals Expenditure                    0
# Total Rice Expenditure                           0
# Meat Expenditure                                 0
# Total Fish and  marine products Expenditure      0
# Fruit Expenditure                                0
# Vegetables Expenditure                           0
# Restaurant and hotels Expenditure                0
# Alcoholic Beverages Expenditure                  0
# Tobacco Expenditure                              0
# Clothing, Footwear and Other Wear Expenditure    0
# Housing and water Expenditure                    0
# Imputed House Rental Value                       0
# Medical Care Expenditure                         0
# ...

# %%
df2 = df1.copy()
df2.head()
# Out:
#    Total Household Income  Region  Total Food Expenditure  \
# 0                  480332       2                  117848
# 1                  198235       2                   67766
# 2                   82785       2                   61609
# 3                  107589       2                   78189
# 4                  189322       2                   94625
#
#    Main Source of Income  Agricultural Household indicator  \
# 0                      3                                 0
# 1                      3                                 0
# 2                      3                                 1
# 3                      3                                 0
# 4                      3                                 0
#
#    Bread and Cereals Expenditure  Total Rice Expenditure  Meat Expenditure  \
# 0                          42140                   38300             24676
# 1                          17329                   13008             17434
# ...

# %%
def onehot_encode(df, column, prefix):
    df = df.copy()
    dummies = pd.get_dummies(df[column], prefix=prefix)
    df = pd.concat([df, dummies], axis=1)
    df = df.drop(column, axis=1)
    return df

# %%
#OneHotEncode categorical variables
nominal_features = [
    ("Region", "reg"),
    ("Main Source of Income", "src_income"),
    ("Household Head Marital Status", "status"),
    ("Household Head Highest Grade Completed", "education"),
    ("Type of Household", "household"),
    ("Type of Building/House", "bldg"),
]

# %%
for column, prefix in nominal_features:
    df2 = onehot_encode(df2, column=column, prefix=prefix)

# %%
df2
# Out:
#        Total Household Income  Total Food Expenditure  \
# 0                      480332                  117848
# 1                      198235                   67766
# 2                       82785                   61609
# 3                      107589                   78189
# 4                      189322                   94625
# ...                       ...                     ...
# 41538                  130636                   81469
# 41539                  119773                   44875
# 41540                  137320                   31157
# 41541                  133171                   45882
# 41542                  129500                   81416
#
#        Agricultural Household indicator  Bread and Cereals Expenditure  \
# 0                                     0                          42140
# 1                                     0                          17329
# 2                                     1                          34182
# ...

# %%
y = df2["Total Household Income"]
X = df2.drop("Total Household Income", axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.7, shuffle=True, random_state=1)

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

# %%
models = {
    "Linear Regression": LinearRegression(),
    "L2-Regularized Linear Regression": Ridge(),
    "L1-Regularized Linear Regression": Lasso(),
    "Huber (Robust) Regression": HuberRegressor(),
    "Linear Kernel Support Vector Machine": LinearSVR(),
    "Decision Tree": DecisionTreeRegressor()
}
for name, model in models.items():
    model.fit(X_train, y_train)
    print(name + " Trained")
# Out:
# Linear Regression Trained
# L2-Regularized Linear Regression Trained
# C:\Users\markk\PycharmProjects\Scrapy101\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.479e+13, tolerance: 1.833e+11
#   model = cd_fast.enet_coordinate_descent(
# L1-Regularized Linear Regression Trained
# Huber (Robust) Regression Trained
# Linear Kernel Support Vector Machine Trained
# Decision Tree Trained

# %%
#RESULTS
print("Model R^2 Scores (Test Set):")
for name, model in models.items():
    print(name + ": {:.4}".format(model.score(X_test, y_test)))
# Out:
# Model R^2 Scores (Test Set):
# Linear Regression: -4.589e+20
# L2-Regularized Linear Regression: 0.8574
# L1-Regularized Linear Regression: 0.8574
# Huber (Robust) Regression: 0.8433
# Linear Kernel Support Vector Machine: -0.4883
# Decision Tree: 0.7488

# %%
#Optimization
l2_reg_strength = 1.0

l2_model = Ridge(alpha=l2_reg_strength)
l2_model.fit(X_train, y_train)

print("Ridge Regression Test R^2 (alpha={}): {:.5f}".format(l2_reg_strength, l2_model.score(X_test, y_test)))
# Out:
# Ridge Regression Test R^2 (alpha=1.0): 0.85737
